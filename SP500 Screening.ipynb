# %%
#import libraries
from yahoofinancials import YahooFinancials
import pandas as pd
import matplotlib.pyplot as plt
import requests
import bs4 as bs
from pandas import DataFrame

# %%
#import s&p500 list
resp = requests.get('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
soup = bs.BeautifulSoup(resp.text,"lxml")
table = soup.find('table',{'class':'wikitable sortable'})
tickers = []
for row in table.findAll('tr')[1:]:
    ticker = row.findAll('td')[0].text.replace('.','-')
    ticker = ticker[:-1]
    tickers.append(ticker)

# %%
#short list for test
tickers_short = ['AAPL', 'MSFT', 'INTC']

# %%
#define screen function
def screen(ticker):
    
    marker = 0

    yahoo_financials_list = YahooFinancials(ticker)
    #store financial statements
    df = yahoo_financials_list.get_financial_stmts('annual', ['income', 'cash', 'balance'])
    
    #store previous 4 yrs data
    df1 = pd.DataFrame(df['incomeStatementHistory'][ticker][3])
    df2 = pd.DataFrame(df['incomeStatementHistory'][ticker][2])
    df3 = pd.DataFrame(df['incomeStatementHistory'][ticker][1])
    df4 = pd.DataFrame(df['incomeStatementHistory'][ticker][0])

    df5 = pd.DataFrame(df['cashflowStatementHistory'][ticker][3])
    df6 = pd.DataFrame(df['cashflowStatementHistory'][ticker][2])
    df7 = pd.DataFrame(df['cashflowStatementHistory'][ticker][1])
    df8 = pd.DataFrame(df['cashflowStatementHistory'][ticker][0])

    df9 = pd.DataFrame(df['balanceSheetHistory'][ticker][3])
    df10 = pd.DataFrame(df['balanceSheetHistory'][ticker][2])
    df11 = pd.DataFrame(df['balanceSheetHistory'][ticker][1])
    df12 = pd.DataFrame(df['balanceSheetHistory'][ticker][0])

    year1=df1.columns[0]
    year2=df2.columns[0]
    year3=df3.columns[0]
    year4=df4.columns[0]

    #store total revenue
    tr1=df1[year1].loc['totalRevenue']
    tr2=df2[year2].loc['totalRevenue']
    tr3=df3[year3].loc['totalRevenue']
    tr4=df4[year4].loc['totalRevenue']

    #store operating income
    oi1=df1[year1].loc['operatingIncome']
    oi2=df2[year2].loc['operatingIncome']
    oi3=df3[year3].loc['operatingIncome']
    oi4=df4[year4].loc['operatingIncome']

    #store operating cash flow
    cfo1=df5[year1].loc['totalCashFromOperatingActivities']
    cfo2=df6[year2].loc['totalCashFromOperatingActivities']
    cfo3=df7[year3].loc['totalCashFromOperatingActivities']
    cfo4=df8[year4].loc['totalCashFromOperatingActivities']

    #goodwill
    if 'goodWill' in df12.index:
        gw4=df12[year4].loc['goodWill']
    else:
        gw4=0

    #stockholder equity
    if 'totalStockholderEquity' in df12.index:
        she4=df12[year4].loc['totalStockholderEquity']
    else:
        she4=0

    #current assets
    if 'totalCurrentAssets' in df12.index:
        ca4=df12[year4].loc['totalCurrentAssets']
    else:
        ca4=0

    #current libabilities
    if 'totalCurrentLiabilities' in df12.index:
        cl4=df12[year4].loc['totalCurrentLiabilities']
    else:
        cl4=0

    #short term debt
    if 'shortLongTermDebt' in df12.index:
        std4=df12[year4].loc['shortLongTermDebt']
    else:
        std4=0

    #long term debt
    if 'longTermDebt' in df12.index:
        ltd4=df12[year4].loc['longTermDebt']
    else:
        ltd4=0
    
    #condition1: 4 consecutive total revenue increase
    #condition2: 4 consecutive operating income increase
    #condition3: operating cash flow is greater than operating income
    #condition4: 2 times stockholder equity is greater than goodwill
    #condition5: current assets are greater than current liabilities
    #condition6: stock holder equity is greater than sum of short term debt and long term debt
    if tr2 > tr1 and tr3 > tr2 and tr4 > tr3 and oi2 > oi1 and oi3 > oi2 and oi4 > oi3 and cfo1 > oi1 and cfo2 > oi2 and cfo3 > oi3 and cfo4 > oi4 and gw4 < 2*she4 and ca4 > cl4 and std4+ltd4 < she4:
        print("This is qualified : " +ticker)
        marker = 1
        return marker
    else:
        print("Not this one : " +ticker)

# %%
#test run with short list
qualified=[]
count=1
for eachstock in tickers_short:
    print(count, eachstock)
    count=count+1
    try:
        if screen(eachstock) ==1:
            qualified.append(eachstock)
    except:
        print ("Error : " + eachstock)
        pass
# Out:
# 1 AAPL
# Not this one : AAPL
# 2 MSFT
# This is qualified : MSFT
# 3 INTC
# Not this one : INTC

# %%
qualified=[]
count=1
for eachstock in tickers:
    print(count, eachstock)
    count=count+1
    try:
        if screen(eachstock) ==1:
            qualified.append(eachstock)
    except:
        print ("Error : " + eachstock)
        pass
# Out:
# 1 MMM
# Not this one : MMM
# 2 ABT
# Not this one : ABT
# 3 ABBV
# Not this one : ABBV
# 4 ABMD
# This is qualified : ABMD
# 5 ACN
# Not this one : ACN
# 6 ATVI
# Not this one : ATVI
# 7 ADBE
# Not this one : ADBE
# 8 AMD
# Not this one : AMD
# 9 AAP
# Not this one : AAP
# 10 AES
# Not this one : AES
# 11 AFL
# Not this one : AFL
# 12 A
# Not this one : A
# 13 APD
# Not this one : APD
# 14 AKAM
# Not this one : AKAM
# 15 ALK
# Not this one : ALK
# 16 ALB
# Not this one : ALB
# 17 ARE
# This is qualified : ARE
# 18 ALXN
# Not this one : ALXN
# 19 ALGN
# Not this one : ALGN
# 20 ALLE
# Not this one : ALLE
# 21 LNT
# Not this one : LNT
# 22 ALL
# Not this one : ALL
# 23 GOOGL
# This is qualified : GOOGL
# 24 GOOG
# This is qualified : GOOG
# 25 MO
# Not this one : MO
# 26 AMZN
# Not this one : AMZN
# 27 AMCR
# Not this one : AMCR
# 28 AEE
# Not this one : AEE
# 29 AAL
# Not this one : AAL
# 30 AEP
# Not this one : AEP
# 31 AXP
# Not this one : AXP
# 32 AIG
# Not this one : AIG
# 33 AMT
# Not this one : AMT
# 34 AWK
# Not this one : AWK
# 35 AMP
# Not this one : AMP
# 36 ABC
# Not this one : ABC
# 37 AME
# Not this one : AME
# 38 AMGN
# Not this one : AMGN
# 39 APH
# Not this one : APH
# 40 ADI
# Not this one : ADI
# 41 ANSS
# Not this one : ANSS
# 42 ANTM
# Not this one : ANTM
# 43 AON
# Not this one : AON
# 44 AOS
# Not this one : AOS
# 45 APA
# Not this one : APA
# 46 AIV
# Not this one : AIV
# 47 AAPL
# Not this one : AAPL
# 48 AMAT
# Not this one : AMAT
# 49 APTV
# Not this one : APTV
# 50 ADM
# Not this one : ADM
# 51 ANET
# Not this one : ANET
# 52 AJG
# This is qualified : AJG
# 53 AIZ
# Not this one : AIZ
# 54 T
# Not this one : T
# 55 ATO
# Not this one : ATO
# 56 ADSK
# Not this one : ADSK
# 57 ADP
# Not this one : ADP
# 58 AZO
# Error : AZO
# 59 AVB
# Not this one : AVB
# 60 AVY
# Not this one : AVY
# 61 BKR
# Not this one : BKR
# 62 BLL
# Not this one : BLL
# 63 BAC
# Not this one : BAC
# 64 BK
# Not this one : BK
# 65 BAX
# This is qualified : BAX
# 66 BDX
# Not this one : BDX
# 67 BRK-B
# Not this one : BRK-B
# 68 BBY
# Not this one : BBY
# 69 BIO
# Not this one : BIO
# 70 BIIB
# Not this one : BIIB
# 71 BLK
# Not this one : BLK
# 72 BA
# Not this one : BA
# 73 BKNG
# Not this one : BKNG
# 74 BWA
# Not this one : BWA
# 75 BXP
# Not this one : BXP
# 76 BSX
# Not this one : BSX
# 77 BMY
# Not this one : BMY
# 78 AVGO
# Not this one : AVGO
# 79 BR
# Not this one : BR
# 80 BF-B
# Not this one : BF-B
# 81 CHRW
# Not this one : CHRW
# 82 COG
# Not this one : COG
# 83 CDNS
# This is qualified : CDNS
# 84 CPB
# Not this one : CPB
# 85 COF
# Not this one : COF
# 86 CAH
# Not this one : CAH
# 87 KMX
# Not this one : KMX
# 88 CCL
# Not this one : CCL
# 89 CARR
# Error : CARR
# 90 CTLT
# Not this one : CTLT
# 91 CAT
# Not this one : CAT
# 92 CBOE
# Not this one : CBOE
# 93 CBRE
# Not this one : CBRE
# 94 CDW
# Not this one : CDW
# 95 CE
# Not this one : CE
# 96 CNC
# Not this one : CNC
# 97 CNP
# Not this one : CNP
# 98 CERN
# Not this one : CERN
# 99 CF
# Not this one : CF
# 100 SCHW
# Not this one : SCHW
# 101 CHTR
# Not this one : CHTR
# 102 CVX
# Not this one : CVX
# 103 CMG
# This is qualified : CMG
# 104 CB
# Not this one : CB
# 105 CHD
# Not this one : CHD
# 106 CI
# Not this one : CI
# 107 CINF
# Not this one : CINF
# 108 CTAS
# Not this one : CTAS
# 109 CSCO
# Not this one : CSCO
# 110 C
# Not this one : C
# 111 CFG
# Not this one : CFG
# 112 CTXS
# Not this one : CTXS
# 113 CLX
# Not this one : CLX
# 114 CME
# Not this one : CME
# 115 CMS
# Not this one : CMS
# 116 KO
# Not this one : KO
# 117 CTSH
# Not this one : CTSH
# 118 CL
# Not this one : CL
# 119 CMCSA
# Not this one : CMCSA
# 120 CMA
# Not this one : CMA
# 121 CAG
# Not this one : CAG
# 122 CXO
# Not this one : CXO
# 123 COP
# Not this one : COP
# 124 ED
# Not this one : ED
# 125 STZ
# Not this one : STZ
# 126 COO
# This is qualified : COO
# 127 CPRT
# Not this one : CPRT
# 128 GLW
# Not this one : GLW
# 129 CTVA
# Not this one : CTVA
# 130 COST
# This is qualified : COST
# 131 CCI
# Not this one : CCI
# 132 CSX
# Not this one : CSX
# 133 CMI
# Not this one : CMI
# 134 CVS
# Not this one : CVS
# 135 DHI
# Not this one : DHI
# 136 DHR
# Not this one : DHR
# 137 DRI
# Not this one : DRI
# 138 DVA
# Not this one : DVA
# 139 DE
# Not this one : DE
# 140 DAL
# Not this one : DAL
# 141 XRAY
# Not this one : XRAY
# 142 DVN
# Not this one : DVN
# 143 DXCM
# Not this one : DXCM
# 144 FANG
# Not this one : FANG
# 145 DLR
# Not this one : DLR
# 146 DFS
# Not this one : DFS
# 147 DISCA
# Not this one : DISCA
# 148 DISCK
# Not this one : DISCK
# 149 DISH
# Not this one : DISH
# 150 DG
# Not this one : DG
# 151 DLTR
# Not this one : DLTR
# 152 D
# Not this one : D
# 153 DPZ
# Not this one : DPZ
# 154 DOV
# Not this one : DOV
# 155 DOW
# Not this one : DOW
# 156 DTE
# Not this one : DTE
# 157 DUK
# Not this one : DUK
# 158 DRE
# Not this one : DRE
# 159 DD
# Not this one : DD
# 160 DXC
# Not this one : DXC
# 161 EMN
# Not this one : EMN
# 162 ETN
# Not this one : ETN
# 163 EBAY
# Not this one : EBAY
# 164 ECL
# Not this one : ECL
# 165 EIX
# Not this one : EIX
# 166 EW
# Not this one : EW
# 167 EA
# Not this one : EA
# 168 EMR
# Not this one : EMR
# 169 ETR
# Not this one : ETR
# 170 EOG
# Not this one : EOG
# 171 EFX
# Not this one : EFX
# 172 EQIX
# Not this one : EQIX
# 173 EQR
# Not this one : EQR
# 174 ESS
# Not this one : ESS
# 175 EL
# Not this one : EL
# 176 ETSY
# Not this one : ETSY
# 177 EVRG
# Not this one : EVRG
# 178 ES
# Not this one : ES
# 179 RE
# Not this one : RE
# 180 EXC
# Not this one : EXC
# 181 EXPE
# Not this one : EXPE
# 182 EXPD
# Not this one : EXPD
# 183 EXR
# Not this one : EXR
# 184 XOM
# Not this one : XOM
# 185 FFIV
# Not this one : FFIV
# 186 FB
# Not this one : FB
# 187 FAST
# Not this one : FAST
# 188 FRT
# Not this one : FRT
# 189 FDX
# Not this one : FDX
# 190 FIS
# Not this one : FIS
# 191 FITB
# Not this one : FITB
# 192 FE
# Not this one : FE
# 193 FRC
# Not this one : FRC
# 194 FISV
# Not this one : FISV
# 195 FLT
# Not this one : FLT
# 196 FLIR
# Not this one : FLIR
# 197 FLS
# Not this one : FLS
# 198 FMC
# Not this one : FMC
# 199 F
# Not this one : F
# 200 FTNT
# This is qualified : FTNT
# 201 FTV
# Not this one : FTV
# 202 FBHS
# Not this one : FBHS
# 203 FOXA
# Not this one : FOXA
# 204 FOX
# Not this one : FOX
# 205 BEN
# Not this one : BEN
# 206 FCX
# Not this one : FCX
# 207 GPS
# Not this one : GPS
# 208 GRMN
# Not this one : GRMN
# 209 IT
# Not this one : IT
# 210 GD
# Not this one : GD
# 211 GE
# Not this one : GE
# 212 GIS
# Not this one : GIS
# 213 GM
# Not this one : GM
# 214 GPC
# Not this one : GPC
# 215 GILD
# Not this one : GILD
# 216 GL
# Not this one : GL
# 217 GPN
# Not this one : GPN
# 218 GS
# Not this one : GS
# 219 GWW
# Not this one : GWW
# 220 HAL
# Not this one : HAL
# 221 HBI
# Not this one : HBI
# 222 HIG
# This is qualified : HIG
# 223 HAS
# Not this one : HAS
# 224 HCA
# Not this one : HCA
# 225 PEAK
# Not this one : PEAK
# 226 HSIC
# Not this one : HSIC
# 227 HSY
# Not this one : HSY
# 228 HES
# Not this one : HES
# 229 HPE
# Not this one : HPE
# 230 HLT
# Not this one : HLT
# 231 HFC
# Not this one : HFC
# 232 HOLX
# Not this one : HOLX
# 233 HD
# Not this one : HD
# 234 HON
# Not this one : HON
# 235 HRL
# Not this one : HRL
# 236 HST
# Not this one : HST
# 237 HWM
# Not this one : HWM
# 238 HPQ
# Not this one : HPQ
# 239 HUM
# Not this one : HUM
# 240 HBAN
# Not this one : HBAN
# 241 HII
# Not this one : HII
# 242 IEX
# Not this one : IEX
# 243 IDXX
# Not this one : IDXX
# 244 INFO
# Not this one : INFO
# 245 ITW
# Not this one : ITW
# 246 ILMN
# This is qualified : ILMN
# 247 INCY
# Not this one : INCY
# 248 IR
# Not this one : IR
# 249 INTC
# Not this one : INTC
# 250 ICE
# Not this one : ICE
# 251 IBM
# Not this one : IBM
# 252 IP
# Not this one : IP
# 253 IPG
# Not this one : IPG
# 254 IFF
# Not this one : IFF
# 255 INTU
# This is qualified : INTU
# 256 ISRG
# Not this one : ISRG
# 257 IVZ
# Not this one : IVZ
# 258 IPGP
# Not this one : IPGP
# 259 IQV
# Not this one : IQV
# 260 IRM
# Not this one : IRM
# 261 JKHY
# Not this one : JKHY
# 262 J
# Not this one : J
# 263 JBHT
# Not this one : JBHT
# 264 SJM
# Not this one : SJM
# 265 JNJ
# Not this one : JNJ
# 266 JCI
# Not this one : JCI
# 267 JPM
# Not this one : JPM
# 268 JNPR
# Not this one : JNPR
# 269 KSU
# Not this one : KSU
# 270 K
# Not this one : K
# 271 KEY
# Not this one : KEY
# 272 KEYS
# Not this one : KEYS
# 273 KMB
# Not this one : KMB
# 274 KIM
# Not this one : KIM
# 275 KMI
# Not this one : KMI
# 276 KLAC
# Not this one : KLAC
# 277 KHC
# Not this one : KHC
# 278 KR
# Not this one : KR
# 279 LB
# Not this one : LB
# 280 LHX
# Not this one : LHX
# 281 LH
# Not this one : LH
# 282 LRCX
# Not this one : LRCX
# 283 LW
# Not this one : LW
# 284 LVS
# Not this one : LVS
# 285 LEG
# Not this one : LEG
# 286 LDOS
# Not this one : LDOS
# 287 LEN
# Not this one : LEN
# 288 LLY
# Not this one : LLY
# 289 LNC
# Not this one : LNC
# 290 LIN
# Not this one : LIN
# 291 LYV
# Not this one : LYV
# 292 LKQ
# Not this one : LKQ
# 293 LMT
# Not this one : LMT
# 294 L
# Not this one : L
# 295 LOW
# Not this one : LOW
# 296 LUMN
# Not this one : LUMN
# 297 LYB
# Not this one : LYB
# 298 MTB
# Not this one : MTB
# 299 MRO
# Not this one : MRO
# 300 MPC
# This is qualified : MPC
# 301 MKTX
# Not this one : MKTX
# 302 MAR
# Not this one : MAR
# 303 MMC
# Not this one : MMC
# 304 MLM
# Not this one : MLM
# 305 MAS
# Not this one : MAS
# 306 MA
# Not this one : MA
# 307 MKC
# Not this one : MKC
# 308 MXIM
# Not this one : MXIM
# 309 MCD
# Not this one : MCD
# 310 MCK
# Not this one : MCK
# 311 MDT
# Not this one : MDT
# 312 MRK
# Not this one : MRK
# 313 MET
# Not this one : MET
# 314 MTD
# Not this one : MTD
# 315 MGM
# Not this one : MGM
# 316 MCHP
# Not this one : MCHP
# 317 MU
# Not this one : MU
# 318 MSFT
# This is qualified : MSFT
# 319 MAA
# Not this one : MAA
# 320 MHK
# Not this one : MHK
# 321 TAP
# Not this one : TAP
# 322 MDLZ
# Not this one : MDLZ
# 323 MNST
# Not this one : MNST
# 324 MCO
# Not this one : MCO
# 325 MS
# Not this one : MS
# 326 MOS
# Not this one : MOS
# 327 MSI
# Not this one : MSI
# 328 MSCI
# Not this one : MSCI
# 329 MYL
# Not this one : MYL
# 330 NDAQ
# Not this one : NDAQ
# 331 NOV
# Not this one : NOV
# 332 NTAP
# Not this one : NTAP
# 333 NFLX
# Not this one : NFLX
# 334 NWL
# Not this one : NWL
# 335 NEM
# Not this one : NEM
# 336 NWSA
# Not this one : NWSA
# 337 NWS
# Not this one : NWS
# 338 NEE
# Not this one : NEE
# 339 NLSN
# Not this one : NLSN
# 340 NKE
# Not this one : NKE
# 341 NI
# Not this one : NI
# 342 NSC
# Not this one : NSC
# 343 NTRS
# Not this one : NTRS
# 344 NOC
# Not this one : NOC
# 345 NLOK
# Not this one : NLOK
# 346 NCLH
# Not this one : NCLH
# 347 NRG
# Not this one : NRG
# 348 NUE
# Not this one : NUE
# 349 NVDA
# Not this one : NVDA
# 350 NVR
# Not this one : NVR
# 351 ORLY
# Not this one : ORLY
# 352 OXY
# Not this one : OXY
# 353 ODFL
# Not this one : ODFL
# 354 OMC
# Not this one : OMC
# 355 OKE
# Not this one : OKE
# 356 ORCL
# Not this one : ORCL
# 357 OTIS
# Error : OTIS
# 358 PCAR
# Not this one : PCAR
# 359 PKG
# Not this one : PKG
# 360 PH
# Not this one : PH
# 361 PAYX
# Not this one : PAYX
# 362 PAYC
# Not this one : PAYC
# 363 PYPL
# This is qualified : PYPL
# 364 PNR
# Not this one : PNR
# 365 PBCT
# Not this one : PBCT
# 366 PEP
# Not this one : PEP
# 367 PKI
# Not this one : PKI
# 368 PRGO
# Not this one : PRGO
# 369 PFE
# Not this one : PFE
# 370 PM
# Not this one : PM
# 371 PSX
# Not this one : PSX
# 372 PNW
# Not this one : PNW
# 373 PXD
# Not this one : PXD
# 374 PNC
# Not this one : PNC
# 375 POOL
# Not this one : POOL
# 376 PPG
# Not this one : PPG
# 377 PPL
# Not this one : PPL
# 378 PFG
# Not this one : PFG
# 379 PG
# Not this one : PG
# 380 PGR
# Not this one : PGR
# 381 PLD
# This is qualified : PLD
# 382 PRU
# Not this one : PRU
# 383 PEG
# Not this one : PEG
# 384 PSA
# This is qualified : PSA
# 385 PHM
# Not this one : PHM
# 386 PVH
# Not this one : PVH
# 387 QRVO
# Not this one : QRVO
# 388 PWR
# Not this one : PWR
# 389 QCOM
# Not this one : QCOM
# 390 DGX
# Not this one : DGX
# 391 RL
# Not this one : RL
# 392 RJF
# Not this one : RJF
# 393 RTX
# Not this one : RTX
# 394 O
# Not this one : O
# 395 REG
# Not this one : REG
# 396 REGN
# Not this one : REGN
# 397 RF
# Not this one : RF
# 398 RSG
# Not this one : RSG
# 399 RMD
# Not this one : RMD
# 400 RHI
# Not this one : RHI
# 401 ROK
# Not this one : ROK
# 402 ROL
# Not this one : ROL
# 403 ROP
# Not this one : ROP
# 404 ROST
# Not this one : ROST
# 405 RCL
# Not this one : RCL
# 406 SPGI
# Not this one : SPGI
# 407 CRM
# Not this one : CRM
# 408 SBAC
# Not this one : SBAC
# 409 SLB
# Not this one : SLB
# 410 STX
# Not this one : STX
# 411 SEE
# Not this one : SEE
# 412 SRE
# Not this one : SRE
# 413 NOW
# This is qualified : NOW
# 414 SHW
# Not this one : SHW
# 415 SPG
# Not this one : SPG
# 416 SWKS
# Not this one : SWKS
# 417 SLG
# Not this one : SLG
# 418 SNA
# Not this one : SNA
# 419 SO
# Not this one : SO
# 420 LUV
# Not this one : LUV
# 421 SWK
# Not this one : SWK
# 422 SBUX
# Not this one : SBUX
# 423 STT
# Not this one : STT
# 424 STE
# This is qualified : STE
# 425 SYK
# Not this one : SYK
# 426 SIVB
# Not this one : SIVB
# 427 SYF
# Not this one : SYF
# 428 SNPS
# Not this one : SNPS
# 429 SYY
# Not this one : SYY
# 430 TMUS
# Not this one : TMUS
# 431 TROW
# Not this one : TROW
# 432 TTWO
# This is qualified : TTWO
# 433 TPR
# Not this one : TPR
# 434 TGT
# Not this one : TGT
# 435 TEL
# Not this one : TEL
# 436 FTI
# Not this one : FTI
# 437 TDY
# Not this one : TDY
# 438 TFX
# Not this one : TFX
# 439 TER
# Not this one : TER
# 440 TXN
# Not this one : TXN
# 441 TXT
# Not this one : TXT
# 442 TMO
# This is qualified : TMO
# 443 TIF
# Not this one : TIF
# 444 TJX
# Not this one : TJX
# 445 TSCO
# Not this one : TSCO
# 446 TT
# Not this one : TT
# 447 TDG
# Not this one : TDG
# 448 TRV
# Not this one : TRV
# 449 TFC
# Not this one : TFC
# 450 TWTR
# Not this one : TWTR
# 451 TYL
# Not this one : TYL
# 452 TSN
# Not this one : TSN
# 453 UDR
# Not this one : UDR
# 454 ULTA
# Not this one : ULTA
# 455 USB
# Not this one : USB
# 456 UAA
# Not this one : UAA
# 457 UA
# Not this one : UA
# 458 UNP
# Not this one : UNP
# 459 UAL
# Not this one : UAL
# 460 UNH
# Not this one : UNH
# 461 UPS
# Not this one : UPS
# 462 URI
# Not this one : URI
# 463 UHS
# Not this one : UHS
# 464 UNM
# Not this one : UNM
# 465 VFC
# Not this one : VFC
# 466 VLO
# Not this one : VLO
# 467 VAR
# Not this one : VAR
# 468 VTR
# Not this one : VTR
# 469 VRSN
# Not this one : VRSN
# 470 VRSK
# Not this one : VRSK
# 471 VZ
# Not this one : VZ
# 472 VRTX
# This is qualified : VRTX
# 473 VIAC
# Not this one : VIAC
# 474 V
# Not this one : V
# 475 VNT
# Not this one : VNT
# 476 VNO
# Not this one : VNO
# 477 VMC
# Not this one : VMC
# 478 WRB
# Not this one : WRB
# 479 WAB
# Not this one : WAB
# 480 WMT
# Not this one : WMT
# 481 WBA
# Not this one : WBA
# 482 DIS
# Not this one : DIS
# 483 WM
# Not this one : WM
# 484 WAT
# Not this one : WAT
# 485 WEC
# Not this one : WEC
# 486 WFC
# Not this one : WFC
# 487 WELL
# Not this one : WELL
# 488 WST
# Not this one : WST
# 489 WDC
# Not this one : WDC
# 490 WU
# Not this one : WU
# 491 WRK
# Not this one : WRK
# 492 WY
# Not this one : WY
# 493 WHR
# Not this one : WHR
# 494 WMB
# Not this one : WMB
# 495 WLTW
# Not this one : WLTW
# 496 WYNN
# Not this one : WYNN
# 497 XEL
# Not this one : XEL
# 498 XRX
# Not this one : XRX
# 499 XLNX
# Not this one : XLNX
# 500 XYL
# Not this one : XYL
# 501 YUM
# Not this one : YUM
# 502 ZBRA
# Not this one : ZBRA
# 503 ZBH
# Not this one : ZBH
# 504 ZION
# Not this one : ZION
# 505 ZTS
# Not this one : ZTS

# %%
qualified
# Out:
# ['ABMD',
#  'ARE',
#  'GOOGL',
#  'GOOG',
#  'AJG',
#  'BAX',
#  'CDNS',
#  'CMG',
#  'COO',
#  'COST',
#  'FTNT',
#  'HIG',
#  'ILMN',
#  'INTU',
#  'MPC',
#  'MSFT',
#  'PYPL',
#  'PLD',
#  'PSA',
#  'NOW',
#  'STE',
#  'TTWO',
#  'TMO',
#  'VRTX']

# %%
|
